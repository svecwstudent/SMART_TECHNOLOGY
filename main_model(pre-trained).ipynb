# %% [markdown]
# # OCR prediction:

# %% [markdown]
# ## importing libraries

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Initialize the EasyOCR reader

# %%
# 'en' is for English, you can add more languages if needed (e.g., ['en', 'fr'] for English and French)
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\easyocr\detection.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(copyStateDict(torch.load(trained_model, map_location=device)))
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\easyocr\recognition.py:169: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)

# %% [markdown]
# ## Function to display the image with bounding boxes around detected text

# %%
def display_image_with_boxes(image, results):
    # Loop through the results (each result contains the bounding box, text, and confidence score)
    for (bbox, text, confidence) in results:
        # Get the four corners of the bounding box
        top_left, top_right, bottom_right, bottom_left = bbox
        top_left = tuple([int(val) for val in top_left])
        bottom_right = tuple([int(val) for val in bottom_right])

        # Draw the bounding box on the image
        cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)

        # Annotate the image with the detected text (case-sensitive)
        cv2.putText(image, text, (top_left[0], top_left[1] - 10), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)

    # Convert the image to RGB format for displaying
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Display the image using Matplotlib
    plt.figure(figsize=(10, 10))
    plt.imshow(image_rgb)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Function to perform OCR on the image and print the detected text

# %%
def extract_text_from_image(image_path):
    # Read the image using OpenCV
    image = cv2.imread(image_path)

    # Use EasyOCR to detect text (case-sensitive)
    results = reader.readtext(image)

    # Display the image with bounding boxes and text
    display_image_with_boxes(image.copy(), results)

    # Print the extracted text (case-sensitive)
    print("Detected Text Details:")
    for (bbox, text, confidence) in results:
        print(f"Text: {text}, Confidence: {confidence:.2f}")

# %% [markdown]
# ## Test the OCR on a sample product image

# %%
image_path = r'C:\Users\DELL\Documents\smart_vision_project\ocr\images\0.jpg'  # Replace with the path to your product image
extract_text_from_image(image_path)
# Out:
# Detected Text Details:
# {'INDIVIDUAL DE TRABAJO A'}
# {'INFERIOR A UN ANO 2015'}
# {'FIJO'}
# {'saber VILMA LORENA PARADA SIERRA,'}
# {'mayor de'}
# {'edad'}
# {'los'}
# {'aparece al pie de su firma, quien obra como'}
# {'REPRESERTANTECiTGde'}
# {'Bogota,'}
# {'OAQ ARTE CONTEMPORANEO BAC, sociedad domiciladE'}
# {'de ia'}
# {'# 57'}
# {'53'}
# {'quien'}
# {'para'}
# {'efectos del'}
# {'presente'}
# {'contrato'}
# {'No'}
# {'ubicada'}
# {'en Ia'}
# {'Carrera'}
# {'Y por Ia otra LUIS EDUARDO BARRERO CORDOBA identificadar'}
# {'una'}
# {'como'}
# {'de su firma,'}
# {'domiciliado'}
# {'en'}
# {'Bogota'}
# {'Cundinamarca V'}
# {'ubicado en la Cr 5 N 49 D 70'}
# {'al pie'}
# {'Ilamara'}
# {'el TRABAJADOR,'}
# {'ha celebrado el presente'}
# {'sucesivo'}
# {'contrato'}
# {'Sur'}
# {'regido ademas por las siguientes clausulas:'}
# {'individual de trabajo,'}
# {'OBJETO. EL EMPLEADOR contrata los servicios personales del TRABAJADOR y este se'}
# {'PRIMERA:'}
# {'al servicio'}
# {'del EMPLEADOR toda'}
# {'su'}
# {'capacidad'}
# {'normal'}
# {'de trabajo,'}
# {'obliga: a)'}
# {'Ponefrunciones propias del oficio como DOMICILIARIO'}
# {'MENSAJERO'}
# {'Y en las labores'}
# {'desempeno de las'}
# {'del mismo, de conformidad'}
# {'con las ordenes'}
# {'instrucciones que le'}
# {'anexas'}
# {'FOMPe earairedeameisrec'}
# {'traves de sus representantes_'}
# {'prestar sus servicios'}
# {'imparta EL'}
# {'al empleador; es decir, a no prestar directa ni indirectamente servicios laborales'}
# {'en forma'}
# {'E@pcIESDORES;'}
# {'ni a trabajar por cuenta propia en el mismo oficio, durante la vigencia de'}
# {'otros'}
# {'dentro del horario laboral que se encuentra comprometido con EL EMPLEADOR; Y c)'}
# {'este contrato'}
# {'reserva sobre los hechos, documentos fisicos ylo electronicos, informaciones y en'}
# {'absoluta'}
# {'sobre todos los asuntos Y materias que Ileguen'}
# {'su conocimiento por causa'}
# {'con ocasion'}
# {'general'}
# {'de SU contrato de trabajo'}
# {'SEGUNDA:'}
# {'REMUNERACION: EL EMPLEADOR pagara al TRABAJADOR por la prestacion desus'}
# {'senvido'}
# {'un'}
# {'salario mensual de SEISCIENTOS CUARENTA'}
# {'CUATRO MIL TRESCIENTOS'}
# {'CINCUENTA (644.350.00), Pagadero los_VEINTIOCHO (28) dias de cada mes Y un Auxilio'}
# {'por Rodamiento'}
# {'por DOSCIENTOS MIL PESOS (200.000,00).'}
# {'Dentro   de'}
# {'este    pago'}
# {'encuentra incluida Ia remuneracion de los descansos dominicales Y festivos de'}
# {'que tratan los'}
# {'Capitulo I y II del Titulo VII del C.S.T, PARAGRAFO PRIMERO Se aclara Y se conviene que en los'}
# {'@sos en'}
# {'que EL TRABAJADOR devengue comisiones'}
# {'cualquiera otra modalidad de salario'}
# {'variable '}
# {'el 82.5% de dichos ingresos, constituye remuneracion de la labor realizada, Y el 17.5%'}
# {'restantes esta destinado'}
# {'remunerar'}
# {'el descanso en los dias dominicales Y festivos'}
# {'de que tratan'}
# {'Ios Capitulos I y II del Titulo VIII del C.S.T. PARAGRAFO SEGUNDO: Las partes acuerdan que en'}
# {'Ios casos en que se le reconozcan al TRABAJADOR beneficios diferentes al salario por concepto de'}
# {'alimentacion '}
# {'a, habitacion'}
# {'0 vivienda, transporte;'}
# {'Y vestuario,'}
# {'se'}
# {'consideraran tales beneficios'}
# {'reconocimientos como no salariales Y por tanto no se tendran en cuenta como factor salarial para la'}
# {'liquidadion de acreencias laborales, ni el pago de aportes parafiscales (diferentes'}
# {'los de Ia'}
# {'seguridad social);'}
# {"de conformidad 'con los Arts 15 y 16 de la ley 50/90, en concordancia con el"}
# {'At.17 de la 344/96.'}
# {'TERCERA: DURACION DEL CONTRATO El termino Iniclal de duracion del contrato sera de TRES'}
# {'(3) meses; desde el 6 de Marzo de 2015'}
# {'Y su fecha de vencimiento sera el'}
# {'6 de Junio de 2015. Si'}
# {'antes de ia fecha de vencimiento de este termino, ninguna de las partes avisare por escritot'}
# {'otra Su '}
# {'determinacion de no prorrogar el contrato, con antelaclon no Inferior'}
# {'(30) dias, este se'}
# {'teteide rij@ rorecgado Por " operiodor GUaont micialrentet elactodon?rratandose de un coagratoc'}
# {'tres'}
# {'fijo'}
# {'de un aro, unicamente podra prorrogarse sucesivamente el contrato hasta poe'}
# {'vaoioreriodos adicionales al inicialeriguales'}
# {'pnoerioresseal cabo de los cuales el termino de'}
# {'renovacion no podra ser'}
# {'un aroy asi sucesivanente: Vacaciones Y Prima de Servicios. En'}
# {'TERMINO'}
# {'CONTRATO'}
# {'suscritos'}
# {'Entre'}
# {'identificado'}
# {'LEGAL'}
# {'BOGOTA'}
# {'Bogota'}
# {'Empresa'}
# {'Ilamara'}
# {'parte'}
# {'por'}
# {'EMPLEADOR'}
# {'aparece'}
# {'quien'}
# {'guardar'}
# {'Jlos'}
# {'Inferior'}
# {'Inferior'}

# %%
def extract_text_from_image(image_path):
    # Read the image using OpenCV
    image = cv2.imread(image_path)

    # Use EasyOCR to detect text (case-sensitive)
    results = reader.readtext(image)

    # Display the image with bounding boxes and text
    display_image_with_boxes(image.copy(), results)

    # Print the extracted text (case-sensitive)
    print("Detected Text Details:")
    for (bbox, text, _) in results:
        print({text})

# %%
# Test the OCR on a sample product image
image_path = r'C:\Users\DELL\Documents\smart_vision_project\ocr\brandname.png'  # Replace with the path to your product image
extract_text_from_image(image_path)
# Out:
# Detected Text Details:
# {'plom'}
# {'mandarin'}
# {'VITAMIN €'}
# {'foaming face wash'}
# {'GLOW BOOST'}
# {'ICn]'}
# {'372102'}
# {'30'}
